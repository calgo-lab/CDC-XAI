# %%
# ❶ تأكد أن المجلد الحالي على المسار
import sys, os
print(os.getcwd())

# ❷ جرّب الاستيراد
from conformal_data_cleaning.cleaner.conformal import ConformalAutoGluonCleaner
print("OK:", ConformalAutoGluonCleaner)
# Out:
# C:\Users\Moham\Masterthesis\conformal_data_cleaning
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       3 print(os.getcwd())
#       5 # ❷ جرّب الاستيراد
# ----> 6 from conformal_data_cleaning.cleaner.conformal import ConformalAutoGluonCleaner
#       7 print("OK:", ConformalAutoGluonCleaner)
#
# ModuleNotFoundError: No module named 'conformal_data_cleaning'

# %%
import conformal_inference
print("conformal_inference OK ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import conformal_inference
#       2 print("conformal_inference OK ✅")
#
# ModuleNotFoundError: No module named 'conformal_inference'
